# %% [markdown]
# ### Data Manipulation with Numpy and Pandas:--

# %% [markdown]
# Data manipulation and analysis are the key tasks in the data scince and data analysis. Pandas provides wide range of functions for data manipulation and analysis making it clean, transform and extract insights from the data.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    OrderID Customer     Product     Category  Quantity  Price   OrderDate
# 0      101     Amit      Laptop  Electronics         1  60000  2025-01-01
# 1      102    Sneha      Mobile  Electronics         2  15000  2025-01-16
# 2      103      Raj      Tablet  Electronics         1  20000  2025-01-31
# 3      104    Pooja  Headphones  Accessories         3   2000  2025-02-15
# 4      105    Vikas      Laptop  Electronics         1  58000  2025-03-02

# %%
df.tail()
# Out:
#    OrderID Customer  Product     Category  Quantity  Price   OrderDate
# 5      106     Neha   Mobile  Electronics         1  16000  2025-03-17
# 6      107    Arjun  Charger  Accessories         4    500  2025-04-01
# 7      108    Meera   Laptop  Electronics         2  61000  2025-04-16
# 8      109     Ravi   Tablet  Electronics         1  21000  2025-05-01
# 9      110    Kiran   Mobile  Electronics         2  15500  2025-05-16

# %%
df.describe()   #gives all the statistical things,
# Out:
#          OrderID   Quantity         Price
# count   10.00000  10.000000     10.000000
# mean   105.50000   1.800000  26900.000000
# std      3.02765   1.032796  23606.496281
# min    101.00000   1.000000    500.000000
# 25%    103.25000   1.000000  15125.000000
# 50%    105.50000   1.500000  18000.000000
# 75%    107.75000   2.000000  48750.000000
# max    110.00000   4.000000  61000.000000

# %%
df.dtypes
# Out:
# OrderID       int64
# Customer     object
# Product      object
# Category     object
# Quantity      int64
# Price         int64
# OrderDate    object
# dtype: object

# %%
df.isnull()
# Out:
#    OrderID  Customer  Product  Category  Quantity  Price  OrderDate
# 0    False     False    False     False     False  False      False
# 1    False     False    False     False     False  False      False
# 2    False     False    False     False     False  False      False
# 3    False     False    False     False     False  False      False
# 4    False     False    False     False     False  False      False
# 5    False     False    False     False     False  False      False
# 6    False     False    False     False     False  False      False
# 7    False     False    False     False     False  False      False
# 8    False     False    False     False     False  False      False
# 9    False     False    False     False     False  False      False

# %%
df.isnull().sum()   #There is no missing values
# Out:
# OrderID      0
# Customer     0
# Product      0
# Category     0
# Quantity     0
# Price        0
# OrderDate    0
# dtype: int64

# %%
df_filled = df.fillna(0)   #wherever there is missing values, that will be filled with zero. and keep that copy.

# %%
df_filled
# Out:
#    OrderID Customer     Product     Category  Quantity  Price   OrderDate
# 0      101     Amit      Laptop  Electronics         1  60000  2025-01-01
# 1      102    Sneha      Mobile  Electronics         2  15000  2025-01-16
# 2      103      Raj      Tablet  Electronics         1  20000  2025-01-31
# 3      104    Pooja  Headphones  Accessories         3   2000  2025-02-15
# 4      105    Vikas      Laptop  Electronics         1  58000  2025-03-02
# 5      106     Neha      Mobile  Electronics         1  16000  2025-03-17
# 6      107    Arjun     Charger  Accessories         4    500  2025-04-01
# 7      108    Meera      Laptop  Electronics         2  61000  2025-04-16
# 8      109     Ravi      Tablet  Electronics         1  21000  2025-05-01
# 9      110    Kiran      Mobile  Electronics         2  15500  2025-05-16

# %%
df1 = pd.read_csv('sales_data_large.csv')
df1.head(10)
# Out:
#    OrderID Customer     Product     Category  Quantity    Price   OrderDate
# 0     1001    Arjun  Headphones  Accessories       4.0  11466.0  2024-01-01
# 1     1002    Pooja      Mobile  Accessories       1.0  53421.0  2024-01-08
# 2     1003    Meera      Laptop  Electronics       4.0  50226.0  2024-01-15
# 3     1004    Vikas      Camera  Electronics       3.0      NaN  2024-01-22
# 4     1005    Arjun     Charger  Accessories       1.0  23177.0  2024-01-29
# 5     1006    Kiran      Tablet  Electronics       4.0  56109.0  2024-02-05
# 6     1007      Raj  Headphones  Electronics       4.0  57161.0  2024-02-12
# 7     1008    Arjun      Camera  Electronics       3.0  31524.0  2024-02-19
# 8     1009    Meera      Tablet  Accessories       1.0  53506.0  2024-02-26
# 9     1010    Vikas      Tablet  Accessories       3.0  15838.0  2024-03-04

# %%
df1.tail()
# Out:
#     OrderID Customer Product     Category  Quantity    Price   OrderDate
# 95     1096    Kiran  Laptop  Electronics       4.0  39013.0  2025-10-27
# 96     1097     Ravi  Tablet  Electronics       3.0  26592.0  2025-11-03
# 97     1098    Arjun  Laptop  Accessories       4.0  11838.0  2025-11-10
# 98     1099     Ravi  Mobile  Accessories       2.0    912.0  2025-11-17
# 99     1100    Meera  Mobile  Electronics       2.0   8043.0  2025-11-24

# %%
df1.describe()
# Out:
#            OrderID   Quantity         Price
# count   100.000000  90.000000     90.000000
# mean   1050.500000   2.844444  35549.311111
# std      29.011492   1.413507  21601.552429
# min    1001.000000   1.000000    912.000000
# 25%    1025.750000   2.000000  15813.250000
# 50%    1050.500000   3.000000  34206.000000
# 75%    1075.250000   4.000000  56536.500000
# max    1100.000000   5.000000  69542.000000

# %%
df1.isnull().sum()
# Out:
# OrderID       0
# Customer      0
# Product       0
# Category      0
# Quantity     10
# Price        10
# OrderDate     0
# dtype: int64

# %%
df1['Quantity_fillNA '] = df1['Quantity'].fillna(df1['Quantity'].mean())  
#new column will be created and values fill there. old column will remain unchanged.

# %%
df1.head(30)
# Out:
#     OrderID Customer     Product     Category  Quantity    Price   OrderDate  \
# 0      1001    Arjun  Headphones  Accessories       4.0  11466.0  2024-01-01
# 1      1002    Pooja      Mobile  Accessories       1.0  53421.0  2024-01-08
# 2      1003    Meera      Laptop  Electronics       4.0  50226.0  2024-01-15
# 3      1004    Vikas      Camera  Electronics       3.0      NaN  2024-01-22
# 4      1005    Arjun     Charger  Accessories       1.0  23177.0  2024-01-29
# 5      1006    Kiran      Tablet  Electronics       4.0  56109.0  2024-02-05
# 6      1007      Raj  Headphones  Electronics       4.0  57161.0  2024-02-12
# 7      1008    Arjun      Camera  Electronics       3.0  31524.0  2024-02-19
# 8      1009    Meera      Tablet  Accessories       1.0  53506.0  2024-02-26
# 9      1010    Vikas      Tablet  Accessories       3.0  15838.0  2024-03-04
# 10     1011    Pooja      Laptop  Electronics       1.0  68527.0  2024-03-11
# ...

# %%
df1.dtypes
# Out:
# OrderID               int64
# Customer             object
# Product              object
# Category             object
# Quantity            float64
# Price               float64
# OrderDate            object
# Quantity_fillNA     float64
# dtype: object

# %%
df1 = df1.rename(columns={'Customer':'Customer_name'})

# %%
df1
# Out:
#     OrderID Customer_name     Product     Category  Quantity    Price  \
# 0      1001         Arjun  Headphones  Accessories       4.0  11466.0
# 1      1002         Pooja      Mobile  Accessories       1.0  53421.0
# 2      1003         Meera      Laptop  Electronics       4.0  50226.0
# 3      1004         Vikas      Camera  Electronics       3.0      NaN
# 4      1005         Arjun     Charger  Accessories       1.0  23177.0
# ..      ...           ...         ...          ...       ...      ...
# 95     1096         Kiran      Laptop  Electronics       4.0  39013.0
# 96     1097          Ravi      Tablet  Electronics       3.0  26592.0
# 97     1098         Arjun      Laptop  Accessories       4.0  11838.0
# 98     1099          Ravi      Mobile  Accessories       2.0    912.0
# 99     1100         Meera      Mobile  Electronics       2.0   8043.0
#
#      OrderDate  Quantity_fillNA
# 0   2024-01-01               4.0
# 1   2024-01-08               1.0
# ...

# %%
df1['Qunatity_new'] = df['Quantity'].astype(float)  #will create new column and will change data type we mentione.

# %%
df1
# Out:
#     OrderID Customer_name     Product     Category  Quantity    Price  \
# 0      1001         Arjun  Headphones  Accessories       4.0  11466.0
# 1      1002         Pooja      Mobile  Accessories       1.0  53421.0
# 2      1003         Meera      Laptop  Electronics       4.0  50226.0
# 3      1004         Vikas      Camera  Electronics       3.0      NaN
# 4      1005         Arjun     Charger  Accessories       1.0  23177.0
# ..      ...           ...         ...          ...       ...      ...
# 95     1096         Kiran      Laptop  Electronics       4.0  39013.0
# 96     1097          Ravi      Tablet  Electronics       3.0  26592.0
# 97     1098         Arjun      Laptop  Accessories       4.0  11838.0
# 98     1099          Ravi      Mobile  Accessories       2.0    912.0
# 99     1100         Meera      Mobile  Electronics       2.0   8043.0
#
#      OrderDate  Quantity_fillNA   Qunatity_new
# 0   2024-01-01               4.0           1.0
# ...

# %%
df1 = df1.rename(columns={'Qunatity_new':'Quantity_new'})

# %%
df1
# Out:
#     OrderID Customer_name     Product     Category  Quantity    Price  \
# 0      1001         Arjun  Headphones  Accessories       4.0  11466.0
# 1      1002         Pooja      Mobile  Accessories       1.0  53421.0
# 2      1003         Meera      Laptop  Electronics       4.0  50226.0
# 3      1004         Vikas      Camera  Electronics       3.0      NaN
# 4      1005         Arjun     Charger  Accessories       1.0  23177.0
# ..      ...           ...         ...          ...       ...      ...
# 95     1096         Kiran      Laptop  Electronics       4.0  39013.0
# 96     1097          Ravi      Tablet  Electronics       3.0  26592.0
# 97     1098         Arjun      Laptop  Accessories       4.0  11838.0
# 98     1099          Ravi      Mobile  Accessories       2.0    912.0
# 99     1100         Meera      Mobile  Electronics       2.0   8043.0
#
#      OrderDate  Quantity_fillNA   Quantity_new
# 0   2024-01-01               4.0           1.0
# ...

# %%
df1['Quantity_increase'] = df['Quantity'].apply(lambda x:x*2)

# %%
df1
# Out:
#     OrderID Customer_name     Product     Category  Quantity    Price  \
# 0      1001         Arjun  Headphones  Accessories       4.0  11466.0
# 1      1002         Pooja      Mobile  Accessories       1.0  53421.0
# 2      1003         Meera      Laptop  Electronics       4.0  50226.0
# 3      1004         Vikas      Camera  Electronics       3.0      NaN
# 4      1005         Arjun     Charger  Accessories       1.0  23177.0
# ..      ...           ...         ...          ...       ...      ...
# 95     1096         Kiran      Laptop  Electronics       4.0  39013.0
# 96     1097          Ravi      Tablet  Electronics       3.0  26592.0
# 97     1098         Arjun      Laptop  Accessories       4.0  11838.0
# 98     1099          Ravi      Mobile  Accessories       2.0    912.0
# 99     1100         Meera      Mobile  Electronics       2.0   8043.0
#
#      OrderDate  Quantity_fillNA   Quantity_new  Quantity_increase
# ...

# %%
df1['Quantity_new'] = df1['Quantity'].fillna(df1['Quantity'].mean()).apply(lambda x: x * 2)

# %%
df1
# Out:
#     OrderID Customer_name     Product     Category  Quantity    Price  \
# 0      1001         Arjun  Headphones  Accessories       4.0  11466.0
# 1      1002         Pooja      Mobile  Accessories       1.0  53421.0
# 2      1003         Meera      Laptop  Electronics       4.0  50226.0
# 3      1004         Vikas      Camera  Electronics       3.0      NaN
# 4      1005         Arjun     Charger  Accessories       1.0  23177.0
# ..      ...           ...         ...          ...       ...      ...
# 95     1096         Kiran      Laptop  Electronics       4.0  39013.0
# 96     1097          Ravi      Tablet  Electronics       3.0  26592.0
# 97     1098         Arjun      Laptop  Accessories       4.0  11838.0
# 98     1099          Ravi      Mobile  Accessories       2.0    912.0
# 99     1100         Meera      Mobile  Electronics       2.0   8043.0
#
#      OrderDate  Quantity_fillNA   Quantity_new
# 0   2024-01-01               4.0           8.0
# ...
